# %%
## ACESSAR BASE DE DADOS

import pandas as pd

contatos_df = pd.read_excel("basededadosteste.xlsx")
display(contatos_df)
# Out:
#       pessoa         numero     cirurgia data_agendamento data_internacao  \
# 0  Jennipher  5521980002500  MAMOPLASTIA       2022-12-10      2022-12-09
# 1   Anderson  5521979716722        HENIA       2022-12-25      2022-12-25
# 2    Eduardo  5521979687944   VASECTOMIA       2022-12-31      2022-12-30
#
#   hora_da_chegada                  jejum  \
# 0        15:00:00   Não precisa de jejum
# 1        09:00:00  Jejum começa as 08:00
# 2        15:00:00   Não precisa de jejum
#
#                                           documentos  \
# 0            Exames, RG, CPF, Comprovante Residencia
# 1            Exames, RG, CPF, Comprovante Residencia
# 2  Passaporte da Clinica da Familia,exames, RG, C...
#
#                             formulario  Unnamed: 9
# 0  https://forms.gle/3PdYfRSBt2wqVcJM8         NaN
# 1  https://forms.gle/3PdYfRSBt2wqVcJM8         NaN
# 2  https://forms.gle/3PdYfRSBt2wqVcJM8         NaN

# %%
import pandas as pd
contatos_df = pd.read_excel("basededadosteste.xlsx")
print('lendo base de dados...')
display(contatos_df)
from selenium import webdriver
print('importado webdriver')
from selenium.webdriver.common.keys import Keys
print('importado keys')
from selenium.webdriver.common.by import By
print('importado By')
import time
import urllib
navegador = webdriver.Chrome()

#Já estamso com o login feito no wapp web
for i, mensagem in enumerate(contatos_df['formulario']):
    ## MONTANDO VARIAVEIS X COLUNAS EXCEL
    pessoa= contatos_df.loc[i, "pessoa"]
    numero= contatos_df.loc[i,"numero"]
    cirurgia= contatos_df.loc[i,"cirurgia"]
    data_agendamento= contatos_df.loc[i,"data_agendamento"]
    data_internacao= contatos_df.loc[i,"data_internacao"]
    hora_da_chegada= contatos_df.loc[i,"hora_da_chegada"]
    jejum= contatos_df.loc[i,"jejum"]
    documentos= contatos_df.loc[i,"documentos"]
    formulario= contatos_df.loc[i,"formulario"]
    ## MONTANDO MENSAGEM
    texto= urllib.parse.quote(f"Oi {pessoa}, \n\n Somos a equipe de comunicação do Hospital Municipal Ronaldo Gazolla. \n\n Estamos alegres em informar que sua cirurgia foi marcada.\n\nCirugia:  {cirurgia} \nData Internação: {data_internacao} - {hora_da_chegada} \nData da Cirurgia:{data_agendamento} \nTrazer os seguintes documentos: {documentos} \nJejum: {jejum} \nTrazer produtos de higiene pessoal. \nNão necessário roupa de cama. \n*Será necessário confirmar sua presença no link:* {formulario} \nEndereço: Av. Pastor Martin Luther King Júnior, 10.976 - Acari, Rio de Janeiro \nTelefone:20884600 \n\nAGUARDAMOS SUA CONFIRMAÇÃO \n")
    link= f"https://web.whatsapp.com/send?phone={numero}&text={texto}"
    navegador.get(link)
    print(f'abrindo link {pessoa}')
    print('esperar 10 segundos')
    time.sleep(10)
    while len(navegador.find_elements(By.XPATH,'//*[@id="main"]/footer/div[2]/div/div[6]/div/div/div/div[1]/div/div/div[2]/span')) < 1:
        time.sleep(1)
        print(f'tentando logar no WAPP...{pessoa}')
        #while len(navegador.find_elements(By.XPATH,'//*[@id="main"]/footer/div[2]/div/div[6]/div/div/div/div[1]/div/div/div[2]/span')) > 0:
        #time.sleep(1)
    navegador.find_element(By.XPATH,'//*[@id="main"]/footer/div[1]/div/span[2]/div/div[2]/div[1]/div/div/p/span').send_keys(Keys.ENTER)
    time.sleep(10)
# Out:
# lendo base de dados...
#       pessoa         numero     cirurgia data_agendamento data_internacao  \
# 0  Jennipher  5521980002500  MAMOPLASTIA         10.12.22        09.12.22
# 1   Anderson  5521979716722        HENIA         25.12.22        25.12.22
# 2    Eduardo  5521979687944   VASECTOMIA         31.12.22        30.12.22
#
#   hora_da_chegada                  jejum  \
# 0             15h   Não precisa de jejum
# 1             09h  Jejum começa as 08:00
# 2             15h   Não precisa de jejum
#
#                                           documentos  \
# 0            Exames, RG, CPF, Comprovante Residencia
# 1            Exames, RG, CPF, Comprovante Residencia
# 2  Passaporte da Clinica da Familia,exames, RG, C...
#
#                             formulario  Unnamed: 9
# 0  https://forms.gle/3PdYfRSBt2wqVcJM8         NaN
# 1  https://forms.gle/3PdYfRSBt2wqVcJM8         NaN
# 2  https://forms.gle/3PdYfRSBt2wqVcJM8         NaN
# importado webdriver
# importado keys
# importado By
# abrindo link Jennipher
# esperar 10 segundos
# tentando logar no WAPP...Jennipher
# tentando logar no WAPP...Jennipher
# tentando logar no WAPP...Jennipher
# tentando logar no WAPP...Jennipher
# tentando logar no WAPP...Jennipher
# tentando logar no WAPP...Jennipher
# tentando logar no WAPP...Jennipher
# tentando logar no WAPP...Jennipher
# tentando logar no WAPP...Jennipher
# tentando logar no WAPP...Jennipher
# tentando logar no WAPP...Jennipher
# tentando logar no WAPP...Jennipher
# tentando logar no WAPP...Jennipher
# tentando logar no WAPP...Jennipher
# tentando logar no WAPP...Jennipher
# tentando logar no WAPP...Jennipher
# tentando logar no WAPP...Jennipher
# tentando logar no WAPP...Jennipher
# tentando logar no WAPP...Jennipher
# tentando logar no WAPP...Jennipher
# tentando logar no WAPP...Jennipher
# tentando logar no WAPP...Jennipher
# tentando logar no WAPP...Jennipher
# tentando logar no WAPP...Jennipher
# tentando logar no WAPP...Jennipher
# tentando logar no WAPP...Jennipher
# abrindo link Anderson
# esperar 10 segundos
# tentando logar no WAPP...Anderson
# tentando logar no WAPP...Anderson
# tentando logar no WAPP...Anderson
# abrindo link Eduardo
# esperar 10 segundos
# tentando logar no WAPP...Eduardo
